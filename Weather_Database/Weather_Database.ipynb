# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
longs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coord_pairs = zip(lats, longs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(coord_pairs)
print(len(coordinates))
# Out:
# 2000

# %%
# Create a list for holding the cities.
cities = []
# Use citipy to get city name of nearest city to each coordinate
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # if the city is not already in the list, add it.
    if city not in cities:
        cities.append(city)
        
# Print length of cities to make sure we have sufficient count 
print(len(cities))
# Out:
# 753

# %%
import requests
from config import weather_api_key
import time
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(30)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | skegness
# Processing Record 4 of Set 1 | bathsheba
# Processing Record 5 of Set 1 | grindavik
# Processing Record 6 of Set 1 | bambous virieux
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | beloha
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | bethel
# Processing Record 11 of Set 1 | castro
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | severo-kurilsk
# Processing Record 16 of Set 1 | aktau
# Processing Record 17 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 20 of Set 1 | ibra
# ...

# %%
weather_df = pd.DataFrame(city_data)

# %%
weather_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Hermanus -34.4187   19.2345     54.81        85          99        5.88
# 1      Bluff -46.6000  168.3333     44.80        79         100       11.36
# 2   Skegness  53.1436    0.3363     93.02        44          71        6.46
# 3  Bathsheba  13.2167  -59.5167     86.61        80          20       20.71
# 4  Grindavik  63.8424  -22.4338     54.07        82          75        4.61
#
#   Country Current Description
# 0      ZA     overcast clouds
# 1      NZ          light rain
# 2      GB       broken clouds
# 3      BB          few clouds
# 4      IS       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
weather_df = weather_df[new_column_order]
weather_df["Lat"] = weather_df["Lat"].round(decimals=2)
weather_df["Lng"] = weather_df["Lng"].round(decimals=2)

# %%
weather_df.head()
# Out:
#         City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0   Hermanus      ZA -34.42   19.23     54.81        85          99
# 1      Bluff      NZ -46.60  168.33     44.80        79         100
# 2   Skegness      GB  53.14    0.34     93.02        44          71
# 3  Bathsheba      BB  13.22  -59.52     86.61        80          20
# 4  Grindavik      IS  63.84  -22.43     54.07        82          75
#
#    Wind Speed Current Description
# 0        5.88     overcast clouds
# 1       11.36          light rain
# 2        6.46       broken clouds
# 3       20.71          few clouds
# 4        4.61       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
weather_df.to_csv(output_data_file, index_label="City_ID")
